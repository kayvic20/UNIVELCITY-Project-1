# %%
import numpy as np
import pandas as pd

# %%
qualified = pd.read_csv("LSETF August 2020 - qualified.csv")
revoked = pd.read_csv("LSETF August 2020 - revoked.csv")
# qualified
revoked
# Out:
#       Sl                          Name                  EmailAddress  \
# 0      1         olajegedea1@gmail.com         olajegedea1@gmail.com
# 1      2       balkizolanike@gmail.com       balkizolanike@gmail.com
# 2      3      semilooretaiwo@gmail.com      semilooretaiwo@gmail.com
# 3      4         afolaesuola@gmail.com         afolaesuola@gmail.com
# 4      5  olatoyeabiolamoses@gmail.com  olatoyeabiolamoses@gmail.com
# ..   ...                           ...                           ...
# 261  258      onyemesimlouis@yahoo.com      onyemesimlouis@yahoo.com
# 262  259    ezekielimole1990@gmail.com    ezekielimole1990@gmail.com
# 263  260           orddanfem@yahoo.com           orddanfem@yahoo.com
# 264  261   umaruthmanizuafah@gmail.com   umaruthmanizuafah@gmail.com
# 265  262      tobibolaji2019@gmail.com      tobibolaji2019@gmail.com
#
#     Phonenumber Attended Date Marks       Status TotalQuestion TotalAttempted  \
# ...

# %%
qualified.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 409 entries, 0 to 408
# Data columns (total 18 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   S/N                              399 non-null    float64
#  1   Timestamp                        399 non-null    object
#  2   EmailAddress                     399 non-null    object
#  3   Firstname                        399 non-null    object
#  4   Lastname                         399 non-null    object
#  5   Phonenumber                      398 non-null    object
#  6   ResidentialAddress               398 non-null    object
#  7   LocalGovernmentArea              399 non-null    object
#  8   Gender                           399 non-null    object
#  9   Dateofbirth                      399 non-null    object
#  10  MaritalStatus                    399 non-null    object
#  11  Selectyou preferredcourse        399 non-null    object
# ...

# %%
revoked.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266 entries, 0 to 265
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Sl              263 non-null    object
#  1   Name            264 non-null    object
#  2   EmailAddress    263 non-null    object
#  3   Phonenumber     14 non-null     object
#  4   Attended Date   1 non-null      object
#  5   Marks           263 non-null    object
#  6   Status          263 non-null    object
#  7   TotalQuestion   263 non-null    object
#  8   TotalAttempted  22 non-null     object
#  9   TotalCorrect    100 non-null    object
# dtypes: object(10)
# memory usage: 10.5+ KB

# %%
email_of_qualified = qualified["EmailAddress"]
email_of_revoked = revoked["EmailAddress"]
email_of_qualified
# email_of_revoked
# Out:
# 0               Idriskuforiji@gmail.com
# 1                     drimz09@gmail.com
# 2                   afofemi86@gmail.com
# 3              gbenrotemitayo@gmail.com
# 4               thisiskelechi@gmail.com
#                      ...
# 404                morbal3594@yahoo.com
# 405    iyanuoluwa.oluwadara01@gmail.com
# 406           titilopemercy22@gmail.com
# 407          falanajoseph2019@gmail.com
# 408     Oyindamolaoronigbagbe@gmail.com
# Name: EmailAddress, Length: 409, dtype: object

# %%
new_Email = pd.merge(qualified, revoked, on="EmailAddress")
new_Email
# Out:
#        S/N        Timestamp                EmailAddress  Firstname Lastname  \
# 0      4.0  7/29/2020 16:19    gbenrotemitayo@gmail.com   Temitayo   Gbenro
# 1      5.0  7/28/2020 16:13     thisiskelechi@gmail.com    Kelechi    Opara
# 2      6.0    8/1/2020 0:18      abarimoshood@gmail.com    Moshood    Abari
# 3      8.0  7/28/2020 22:18      ashiwajutobi@gmail.com       TOBI  ASIWAJU
# 4      9.0    8/4/2020 6:54   adekuemmanuel55@gmail.com  Emmanuel     Adeku
# ..     ...              ...                         ...        ...      ...
# 317  345.0   8/9/2020 22:15       praisetaiwo@gmail.com     Praise    Taiwo
# 318  350.0   8/8/2020 13:47    kehindejohn018@gmail.com    Kehinde     John
# 319  351.0  8/11/2020 15:55     okoriepsymmun@gmail.com      Simon   Okorie
# 320  352.0   7/28/2020 7:26          ybdtola1@gmail.com    ADETOLA  OYEBODE
# 321  360.0   8/13/2020 9:59  babatunde4real44@gmail.com      Yusuf    Abeeb
#
# ...

# %%
new_filtered = new_Email[["EmailAddress", "Phonenumber_x"]]
new_filtered
# Out:
#                    EmailAddress Phonenumber_x
# 0      gbenrotemitayo@gmail.com    8183739297
# 1       thisiskelechi@gmail.com    9029577152
# 2        abarimoshood@gmail.com    8095930783
# 3        ashiwajutobi@gmail.com    7033632582
# 4     adekuemmanuel55@gmail.com    8177623119
# ..                          ...           ...
# 317       praisetaiwo@gmail.com    9095615167
# 318    kehindejohn018@gmail.com    8147773949
# 319     okoriepsymmun@gmail.com    8161252450
# 320          ybdtola1@gmail.com      2.35E+12
# 321  babatunde4real44@gmail.com    7033720478
#
# [322 rows x 2 columns]

# %%
new_filtered.to_csv('new_filtered.csv')
